# %%
# Task 1

class Student:
    ID = 0

    def __init__(self, name, dept, age, cgpa):
        Student.ID += 1
        self.name = name
        self.dept = dept
        self.age = age
        self.cgpa = cgpa
    
    @classmethod
    def from_String(cls, info):
        name, dept, age, cg = info.split("-")
        obj = cls(name, dept, int(age), float(cg))
        return obj

    def get_details(self):
        print(f"ID: {Student.ID}")
        print(f"Name: {self.name}")
        print(f"Department: {self.dept}")
        print(f"Age: {self.age}")
        print(f"CGPA: {self.cgpa}")


s1 = Student("Samin", "CSE", 21, 3.91)
s1.get_details()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.get_details()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.get_details() 
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.get_details()

print("\n"+"#"*40+"\n")
print("Class Variables: Class variables are defined within a class and can be inherited by all the instances of that class.")
print("Instance Variables: Instance variables are created for each instance of the class and each instance's copy of the variable are different and unique.")

print("\n"+"#"*40+"\n")
print("Instance Methods: Instance methods are the methods created in a class, which can access all the instance variables of a class through the mandatory self parameter. And can be called with class objects.")
print("Class methods: Class methods are needed to be flagged as '@classmethod' and takes cls as a parameter and can only access the class variables and not the instance variables. And cannot be called with class objects.")
# Out:
# ID: 1
# Name: Samin
# Department: CSE
# Age: 21
# CGPA: 3.91
# -----------------------
# ID: 2
# Name: Fahim
# Department: ECE
# Age: 21
# CGPA: 3.85
# -----------------------
# ID: 3
# Name: Tahura
# Department: EEE
# Age: 22
# CGPA: 3.01
# -----------------------
# ID: 4
# Name: Sumaiya
# Department: BBA
# Age: 23
# CGPA: 3.96
#
# ########################################
#
# Class Variables: Class variables are defined within a class and can be inherited by all the instances of that class.
# Instance Variables: Instance variables are created for each instance of the class and each instance's copy of the variable are different and unique.
#
# ########################################
#
# Instance Methods: Instance methods are the methods created in a class, which can access all the instance variables of a class throught the mandatory self parameter. And can be called with class objects.
# ...

# %%
# Task 2

class Assassin:
    numbers = 0
    
    def __init__(self, name, success_rate):
        Assassin.numbers += 1
        self.name = name
        self.success_rate = success_rate
    
    @classmethod
    def failureRate(cls, name, failure_rate):
        obj = cls(name, 100-failure_rate)
        return obj
    
    @classmethod
    def failurePercentage(cls, name, failure_percentage):
        obj = cls(name, 100-int(failure_percentage[:-1]))
        return obj

    def printDetails(self):
        print(f"Name: {self.name}")
        print(f"Success rate: {self.success_rate}%")
        print(f"Total number of Assassin: {Assassin.numbers}")
    
john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()
# Out:
# Name: John Wick
# Success rate: 100%
# Total number of Assassin: 1
# ...
# Name: Nagisa
# Success rate: 80%
# Total number of Assassin: 2
# ...
# Name: Akabane
# Success rate: 90%
# Total number of Assassin: 3

# %%
# Task 3

class Passenger:
    count = 0

    def __init__(self, name):
        Passenger.count += 1
        self.name = name
        self.fare = 450

    def set_bag_weight(self, weight):
        if weight < 20:
            self.fare += 0
        elif 21 < weight < 50:
            self.fare += 50
        elif weight > 50:
            self.fare += 100
    
    def printDetail(self):
        print(f"Name: {self.name}")
        print(f"Bus Fare: {self.fare} taka")


print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("Carol")
p2.set_bag_weight(10)
p3 = Passenger("Mike")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("Total Passenger:", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name: Jack
# Bus Fare: 550 taka
# ...
# Name: Carol
# Bus Fare: 450 taka
# ...
# Name: Mike
# Bus Fare: 500 taka
# ...
# Total Passenger: 3

# %%
# Task 4

class Travel:
    count = 0

    def __init__(self, source, dest):
        Travel.count += 1
        self.source = source
        self.dest = dest
        self.time = 1
    
    def display_travel_info(self):
        return f"Source: {self.source}\nDestination: {self.dest}\nFlight Time: {self.time}:00"
    
    def set_source(self, source):
        self.source = source

    def set_destination(self, dest):
        self.dest = dest

    def set_time(self, time):
        self.time = time

print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source: Dhaka
# Destination: India
# Flight Time: 1:00
# ...
# Source: Kuala Lampur
# Destination: Dhaka
# Flight Time: 23:00
# ...
# Source: Dhaka
# Destination: Germany
# Flight Time: 15:00
# ...
# Source: Malaysia
# Destination: Canada
# Flight Time: 9:00
# ...
# No. of Traveller = 4

# %%
# Task 5

class Employee:
    current_year = 2022

    def __init__(self, name, wp):
        self.name = name
        self.workingPeriod = wp

    @classmethod
    def employeeByJoiningYear(cls, name, year):
        wp = Employee.current_year - year
        obj = cls(name, wp)
        return obj
    
    @staticmethod
    def experienceCheck(exp, gender):
        pr = "He"
        if gender == "female":
            pr = "She"
        
        if exp < 3:
            return f"{pr} is not experienced"
        return f"{pr} is experienced"


employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))
# Out:
# 3
# 6
# Dororo
# Harry
# He is not experienced
# She is experienced

# %%
# Task 6

class Laptop:
    laptopCount = 0

    def __init__(self, name, count):
        self.name = name
        self.count = count
        Laptop.laptopCount += count
    
    @staticmethod
    def advantage():
        print("Laptops are portable")
    
    @classmethod
    def resetCount(cls):
        Laptop.laptopCount = 0


lenovo = Laptop("Lenovo", 5)
dell = Laptop("Dell", 7)
print(lenovo.name, lenovo.count)
print(dell.name, dell.count)
print("Total number of Laptops", Laptop.laptopCount)
Laptop.advantage()
Laptop.resetCount()
print("Total number of Laptops", Laptop.laptopCount)
# Out:
# Lenovo 5
# Dell 7
# Total number of Laptops 12
# Laptops are portable
# Total number of Laptops 0

# %%
# Task 7

class Cat:
    Number_of_cats = 0

    def __init__(self, color, action):
        Cat.Number_of_cats += 1
        self.color = color
        self.action = action
    
    @classmethod
    def no_parameter(cls):
        return cls("White", "sitting")

    @classmethod
    def first_parameter(cls, color):
        return cls(color, "sitting")
    
    @classmethod
    def second_parameter(cls, action):
        return cls("White", action)
    
    def changeColor(self, color):
        self.color = color


    def printCat(self):
        print(f"{self.color} cat is {self.action}")

print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# White cat is playing
# Blue cat is sitting
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
# Task 8

from math import pi

class Cylinder:
    radius = 5
    height = 18

    def __init__(self, radius, height):
        print(f"Default radius={Cylinder.radius} and height={Cylinder.height}")
        Cylinder.radius = radius
        Cylinder.height = height
        print(f"Updated radius={radius} and height={height}")
    
    @classmethod
    def swap(cls, height, radius):
        return cls(radius, height)
    
    @classmethod
    def changeFormat(cls, string):
        radius, height = string.split("-")
        return cls(float(radius), float(height))

    @staticmethod
    def area(r, h):
        ans = 2*pi*(r**2) + 2*pi*r*h
        print(f"Area: {ans}")
    
    @staticmethod
    def volume(r, h):
        ans = pi*(r**2)*h
        print(f"Volume: {ans}")


c1 = Cylinder(0,0)
Cylinder.area(c1.radius,c1.height)
Cylinder.volume(c1.radius,c1.height)
print("===============================")
c2 = Cylinder.swap(8,3)
c2.area(c2.radius,c2.height)
c2.volume(c2.radius,c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius,c3.height)
c3.volume(c3.radius,c3.height)
print("===============================")
Cylinder(0.3,5.56).area(Cylinder.radius,Cylinder.height)
print("===============================")
Cylinder(3,5).volume(Cylinder.radius,Cylinder.height)
# Out:
# Default radius=5 and height=18
# Updated radius=0 and height=0
# Area: 0.0
# Volume: 0.0
# ...
# Default radius=5 and height=18
# Updated radius=3 and height=8
# Area: 207.34511513692635
# Volume: 226.1946710584651
# ...
# Default radius=5 and height=18
# Updated radius=7.0 and height=13.0
# Area: 879.645943005142
# Volume: 2001.1945203366981
# ...
# Default radius=5 and height=18
# Updated radius=0.3 and height=5.56
# Area: 722.5663103256525
# ...
# Default radius=5 and height=18
# Updated radius=3 and height=5
# Volume: 1413.7166941154069

# %%
# Task 9

class Student:
    student_count = 0
    bracu_students = 0
    other_students = 0

    def __init__(self, name, dept, ins="BRAC University"):
        Student.student_count += 1
        self.name = name
        self.dept = dept
        self.ins = ins
        if ins == "BRAC University":
            Student.bracu_students += 1
        else:
            Student.other_students += 1
    
    @classmethod
    def createStudent(cls, name, dept, ins="BRAC University"):
        return cls(name, dept, ins)

    @classmethod
    def printDetails(cls):
        print(f"Total Student(s): {cls.student_count}")
        print(f"BRAC University Student(s): {cls.bracu_students}")
        print(f"Other Institution Student(s): {cls.other_students}")

    def individualDetail(self):
        print(f"Name: {self.name}")
        print(f"Department: {self.dept}")
        print(f"Institution: {self.ins}")

 
Student.printDetails()
print('#########################')
mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()
print('========================')
harry = Student.createStudent('Harry Potter', "Defence Against Dark Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()
print('=========================')
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()
# Out:
# Total Student(s): 0
# BRAC University Student(s): 0
# Other Institution Student(s): 0
# #########################
# Name: Mikasa Ackerman
# Department: CSE
# Institution: BRAC University
# ------------------------------------------
# Total Student(s): 1
# BRAC University Student(s): 1
# Other Institution Student(s): 0
# ...
# Name: Harry Potter
# Department: Defence Against Dark Arts
# Institution: Hogwarts School
# -------------------------------------------
# Total Student(s): 2
# BRAC University Student(s): 1
# Other Institution Student(s): 1
# ...
# Name: Levi Ackerman
# Department: CSE
# Institution: BRAC University
# --------------------------------------------
# Total Student(s): 3
# BRAC University Student(s): 2
# Other Institution Student(s): 1

# %%
# Task 10

class SultansDine:
    totalBranch = 0
    totalSell = 0
    branchInfo = []

    def __init__(self, location):
        SultansDine.totalBranch += 1
        self.location = location
        self.branchSell = 0
        self.sellShare = 0

    def sellQuantity(self, quantity):
        branchSell = 0
        if quantity < 10:
            branchSell = quantity * 300
        elif quantity < 20:
            branchSell = quantity * 350
        else:
            branchSell = quantity * 400
        self.branchSell = branchSell
        SultansDine.totalSell += self.branchSell
        self.sellShare = (self.branchSell/SultansDine.totalSell) * 100
        SultansDine.branchInfo.append(f"Branch Name: {self.location}, Branch Sell: {self.branchSell} Taka \nBranch consists of total sell's: {self.sellShare: .2f}%\n")


    def branchInformation(self):
        print(f"Branch Name: {self.location}")
        print(f"Branch Sell: {self.branchSell}")
    
    @classmethod
    def details(cls):
        print(f"Total Number of branch(s): {cls.totalBranch}")
        print(f"Total Sell: {cls.totalSell} Taka")
        print(f"{''.join(cls.branchInfo)}")

SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
#
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000
# -----------------------------------------
# Total Number of branch(s): 1
# Total Sell: 10000 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's:  100.00%
# ...
# Branch Name: Baily Road
# Branch Sell: 5250
# -----------------------------------------
# Total Number of branch(s): 2
# Total Sell: 15250 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's:  100.00%Branch Name: Baily Road, Branch Sell: 5250 Taka
# Branch consists of total sell's:  34.43%
# ...
# Branch Name: Gulshan
# Branch Sell: 2700
# -----------------------------------------
# Total Number of branch(s): 3
# Total Sell: 17950 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's:  100.00%Branch Name: Baily Road, Branch Sell: 5250 Taka
# ...

# %%
# Task 11

class Puzzle:
    x = 0

    def methodA(self):
        Puzzle.x = 5
        z = Puzzle.x + self.methodB(Puzzle.x)
        print(Puzzle.x, z)
        z = self.methodB(z + 2) + Puzzle.x
        print(Puzzle.x, z)
        self.methodB(Puzzle.x, z)
        print(Puzzle.x, z)
    def methodB(self, *args):
        if len(args) == 1:
            y = args[0]
            Puzzle.x = y + Puzzle.x
            print(Puzzle.x, y)
            return Puzzle.x + 3
        else:
            z, x = args
            z = z + 1
            x = x + 1
            print(z, x)

p = Puzzle()
p.methodA()
p.methodA()
p = Puzzle()
p.methodA()
p.methodB(7)
# Out:
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 37 7
# 40

# %%
# Task 12

class FinalT6A:
    temp = 3
    def __init__(self, x, p):
        self.sum, self.y = 0, 2
        FinalT6A.temp += 3
        self.y = self.temp - p
        self.sum = self.temp + x
        print(x, self.y, self.sum)

    def methodA(self):
        x, y = 0, 0
        y = y + self.y
        x = self.y + 2 + self.temp
        self.sum = x + y + self.methodB(self.temp, y)
        print(x, y, self.sum)
    
    def methodB(self, temp, n):
        x = 0
        FinalT6A.temp += 1
        self.y = self.y + (FinalT6A.temp)
        FinalT6A.temp -= 1
        x = x + 2 + n
        self.sum = self.sum + x + self.y
        print(x, self.y, self.sum)
        return self.sum


q1 = FinalT6A(2,1)
q1.methodA()
q1.methodA()
# Out:
# 2 5 8
# 7 12 27
# 13 5 45
# 14 19 78
# 20 12 110

# %%
# Task 13

class A:
    temp = 4
    def __init__(self):
        print(f"A.temp {A.temp}")
        self.y = self.temp - 2
        print(f"self.y {self.y}")
        self.sum = self.temp + 1
        print(f"self.sum {self.sum}")
        A.temp -= 2
        print(f"A.temp {A.temp}")
        self.methodA(3, 4)
    def methodA(self, m, n):
        x = 0
        self.y = self.y + m + (self.temp)
        print(f"self.y {self.y}")
        A.temp += 1
        print(f"A.temp {A.temp}")
        x = x + 1 + n
        print(f"x {x}")
        self.sum = self.sum + x + self.y
        print(f"self.sum {self.sum}")
        print(x, self.y, self.sum)

class B:
    x = 0
    def __init__(self, b = None):
        self.y, self.temp, self.sum = 5, -5, 2
        print(f"self.y {self.y} self.temp {self.temp} self.sum {self.sum}")

        if b == None:
            self.y = self.temp + 3
            print(f"self.y {self.y}")
            self.sum = 3 + self.temp + 2
            print(f"self.sum {self.sum}")
            self.temp -= 2
            print(f"self.temp {self.temp}")
        else:
            self.sum = b.sum
            print(f"self.sum {self.sum}")
            B.x = b.x
            print(f"B.x {b.x}")
            b.methodB(2, 3)
    def methodA(self, m, n):
        print("B method A start")
        x = 2
        self.y = self.y + m + (self.temp)
        print(f"self.y {self.y}")
        self.temp += 1
        print(f"self.temp {self.temp}")
        x = x + 5 + n
        print(f"x {x}")
        self.sum = self.sum + x + self.y
        print(f"self.sum {self.sum}")
        print(x, self.y, self.sum)
        print("B method A end")

    def methodB(self, m, n):
        print("B Method B start")
        y = 0
        y = y + self.y
        print(f"y {y}")
        B.x = self.y + 2 + self.temp
        print(f"B.x {B.x}")
        self.methodA(self.x, y)
        self.sum = self.x + y + self.sum
        print(f"self.sum {self.sum}")
        print(self.x, y, self.sum)
        print("B Method B end")


a1 = A()
b1 = B()
b2 = B(b1)
b1.methodA(1, 2)
b2.methodB(3, 2)
# Out:
# A.temp 4
# self.y 2
# self.sum 5
# A.temp 2
# self.y 7
# A.temp 3
# x 5
# self.sum 17
# 5 7 17
# self.y 5 self.temp -5 self.sum 2
# self.y -2
# self.sum 0
# self.temp -7
# self.y 5 self.temp -5 self.sum 2
# self.sum 0
# B.x 0
# B Method B start
# y -2
# B.x -7
# B method A start
# self.y -16
# self.temp -6
# x 5
# self.sum -11
# 5 -16 -11
# B method A end
# self.sum -20
# -7 -2 -20
# B Method B end
# B method A start
# self.y -21
# self.temp -5
# x 9
# self.sum -32
# 9 -21 -32
# B method A end
# B Method B start
# y 5
# B.x 2
# B method A start
# self.y 2
# self.temp -4
# x 12
# self.sum 14
# 12 2 14
# B method A end
# self.sum 21
# 2 5 21
# B Method B end
